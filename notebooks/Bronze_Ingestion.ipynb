# %%
customers_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv("Files/customers.csv")
)

products_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv("Files/products.csv")
)

stores_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv("Files/stores.csv")
)

sales_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv("Files/sales.csv")
)

inventory_df = (
    spark.read
    .option("header", "true")
    .option("inferSchema", "true")
    .csv("Files/inventory.csv")
)
# Out:
# StatementMeta(, f280d3b7-ce54-4152-8d29-c3a79ef802af, 3, Finished, Available, Finished, False)

# %%
print("Customers:", customers_df.count())
print("Products:", products_df.count())
print("Stores:", stores_df.count())
print("Sales:", sales_df.count())
print("Inventory:", inventory_df.count())
# Out:
# StatementMeta(, f280d3b7-ce54-4152-8d29-c3a79ef802af, 4, Finished, Available, Finished, False)
# Customers: 1000
# Products: 200
# Stores: 20
# Sales: 20000
# Inventory: 4000

# %%
display(customers_df.limit(10))
# Out:
# StatementMeta(, f280d3b7-ce54-4152-8d29-c3a79ef802af, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 5974b701-6439-49a3-9e10-f87f49540900)

# %%
display(sales_df.limit(10))
# Out:
# StatementMeta(, f280d3b7-ce54-4152-8d29-c3a79ef802af, 6, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, f129c584-e2d0-4921-9b50-52751406e463)

# %%
customers_df.write.mode("overwrite").format("delta").saveAsTable("bronze_customers")

products_df.write.mode("overwrite").format("delta").saveAsTable("bronze_products")

stores_df.write.mode("overwrite").format("delta").saveAsTable("bronze_stores")

sales_df.write.mode("overwrite").format("delta").saveAsTable("bronze_sales")

inventory_df.write.mode("overwrite").format("delta").saveAsTable("bronze_inventory")
# Out:
# StatementMeta(, f280d3b7-ce54-4152-8d29-c3a79ef802af, 7, Finished, Available, Finished, False)
